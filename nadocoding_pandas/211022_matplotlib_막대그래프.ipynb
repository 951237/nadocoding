# %%
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.font_manager as fm
matplotlib.rcParams['font.family'] = 'UnDotum' # 리눅스 돋움체 설정
matplotlib.rcParams['font.size'] = 15 # 폰트 크기
matplotlib.rcParams['axes.unicode_minus'] = False  # - 마이너스 글꼴 오류 처리

# %%
label = ['강백호', '서태웅', '정대만']
values = [190, 180, 184]
colors = ['red', 'blue', 'green']
plt.bar(label, values)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(label, values, color='red')
# Out:
# <BarContainer object of 3 artists>

# %%
plt.ylim(175, 195)  # y축의 값위 범위를 지정
plt.bar(label, values, width=0.5, color=colors)  # 각 값별로 색깔을 다르게, 그래프 폭을 조정함.
# Out:
# <BarContainer object of 3 artists>

# %%
# 글자 기울이기
plt.bar(label, values, width=0.3)
plt.xticks(rotation = 45)
plt.yticks(rotation = 45)
# Out:
# (array([  0.,  50., 100., 150., 200.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# x축의 레이블 바꾸기
label = ['강백호', '서태웅', '정대만']
values = [190, 180, 184]
ticks = ['1번학생','2번학생', '3번학생']
plt.bar(label, values)
plt.xticks(label, ticks, rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x6d366b08>,
# ...
#  [Text(0.0, 0, '1번학생'), Text(1.0, 0, '2번학생'), Text(2.0, 0, '3번학생')])
